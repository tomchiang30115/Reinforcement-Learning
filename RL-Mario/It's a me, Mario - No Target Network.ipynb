# %%
###########
# Imports #
###########

# Mario Envrionment Libraries
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# Other Libraries
import gym
from gym.wrappers import GrayScaleObservation, ResizeObservation, FrameStack
from stable_baselines3.common.atari_wrappers import MaxAndSkipEnv
from matplotlib import pyplot as plt
from collections import deque
import torch.nn as nn
import torch
import time
import random
import copy
import numpy as np
import torchvision
import os

# %%
###############
# Agent Class #
###############

class Agent:
    def __init__(self, num_actions, replay_buffer_size=100000, num_replay_samples=32, model_path=None):
        self.num_actions = num_actions
        self.replay_buffer = deque(maxlen=replay_buffer_size) # Stores up to the given number of past experiences (called 'D' in slides)
        self.num_replay_samples = num_replay_samples
        self.epsilon = 1.0
        self.epsilon_decay = 0.99999975
        self.epsilon_min = 0.1
        self.gamma = 0.9
        self.loss = torch.nn.HuberLoss()
        self.learning_rate = 0.000025
        
        # Allow torch to use GPU for processing, if avaiable
        device = torch.device('cpu')
        if torch.cuda.is_available():
            device = torch.device('cuda')
        print("Torch device: ", device)
        
        self.q1 = nn.Sequential(
            nn.Conv2d(in_channels=4, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, num_actions)
        ).to(device)
        
        self.previous_episodes = 0
        self.previous_steps = 0
        
        self.optimizer = torch.optim.Adam(self.q1.parameters(), lr=self.learning_rate)
        
        # Check if previously trained model has been provided
        if model_path != None:
            loaded_model = torch.load(model_path)
            self.q1.load_state_dict(loaded_model['model_state_dict'])
            self.q1.train()
            self.optimizer = torch.optim.Adam(self.q1.parameters(), lr=loaded_model['learning_rate'])
            self.optimizer.load_state_dict(loaded_model['optimizer_state_dict'])
            self.previous_episodes = loaded_model['num_episodes']
            self.previous_steps = loaded_model['num_steps']
            self.epsilon = loaded_model['epsilon']
    
    def decay_epsilon(self):
        self.epsilon *= self.epsilon_decay
        if self.epsilon < self.epsilon_min:
            self.epsilon = self.epsilon_min
    
    def update_logs(self, save_location, log_interval, episode, step, average_episode_loss, 
                    average_episode_reward, average_episode_distance, flag_count, death_count, timeout_count):
        print("Updating logs")
        self.log_file = open(save_location + 'log.txt', 'a')
        self.log_file.write(str(episode+self.previous_episodes) + "," 
                            + str(step+self.previous_steps) + "," 
                            + str(average_episode_reward) + ","
                            + str(average_episode_distance) + ","
                            + str(average_episode_loss) + ","
                            + str(flag_count) + ","
                            + str(death_count) + ","
                            + str(timeout_count) + ","
                            + str(self.epsilon) + "\n")
        self.log_file.close()
    
    def save_model(self, step, episode, save_location):
        torch.save({
            'model_state_dict': self.q1.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'loss': self.loss,
            'num_episodes': episode + self.previous_episodes,
            'num_steps': step + self.previous_steps,
            'epsilon': self.epsilon,
            'learning_rate': self.learning_rate
        },
            save_location + str(step + self.previous_steps) + '.pth')
    
    def get_action(self, state):
        # epsilon-greedy policy
        if (random.uniform(0, 1) < self.epsilon):
            # Explore randomly
            random_action = random.randint(0, self.num_actions-1)
            #print("Selected action:", random_action)
            return random_action
        else:
            # Follow policy greedily (A_t = argmax_q1(S_t, a, theta1))
            state = torch.tensor(state.__array__()).squeeze().cuda() # Squeeze to get rid of uneccessary channel dimension
            #print(state.shape)
            state = torchvision.transforms.functional.convert_image_dtype(state, dtype=torch.float)
            state = state.unsqueeze(0) # Add first dimension to match shape of minibatches being fed into network
            #print(state.shape)
            
            action_values = self.q1(state)
            #print(action_values)
            best_action = torch.argmax(action_values, axis=1).item()
            #print("Selected action:", best_action)
            return best_action
        
    def add_to_replay_buffer(self, state, chosen_action, reward, next_state, done):
        # Convert to tensors
        state = torch.tensor(state.__array__()).squeeze().cuda()
        chosen_action = torch.tensor([chosen_action]).cuda()
        reward = torch.tensor([reward]).cuda()
        next_state = torch.tensor(next_state.__array__()).squeeze().cuda()
        done = torch.tensor([int(done)]).cuda()
        
        self.replay_buffer.append((state, chosen_action, reward, next_state, done))
        
    def perform_updates(self):
        num_samples = self.num_replay_samples
        
        # Check if replay buffer has enough samples for full minibatch
        # Don't perform updates until enough samples in replay buffer
        if len(self.replay_buffer) < self.num_replay_samples:
            #print("Replay buffer only has", len(self.replay_buffer), "transitions. Skipping updates...")
            return
        
        # Randomly select a number of transitions from the replay buffer
        minibatch = random.sample(self.replay_buffer, self.num_replay_samples)
        state, chosen_action, reward, next_state, done = map(torch.stack, zip(*minibatch)) # https://pytorch.org/tutorials/intermediate/mario_rl_tutorial.html?highlight=transformer
        chosen_action = chosen_action.squeeze()
        reward = reward.squeeze()
        done = done.squeeze()
        #print("Shape of batch:", next_state.shape)
        
        # Get TD Value Estimate
        state = torchvision.transforms.functional.convert_image_dtype(state, dtype=torch.float)
        estimated_value = self.q1(state)[np.arange(0, self.num_replay_samples), chosen_action]
        
        # Get TD Value Target
        with torch.no_grad(): # Disable gradient calculation: https://pytorch.org/docs/stable/generated/torch.no_grad.html
            next_state = torchvision.transforms.functional.convert_image_dtype(next_state, dtype=torch.float)
            next_state_Q = self.q1(next_state)
            best_action = torch.argmax(next_state_Q, axis=1)
            next_Q = self.q1(next_state)[np.arange(0, self.num_replay_samples), best_action]

        target_value = (reward + (1 - done.float()) * self.gamma * next_Q).float()
        # print("TD Target:", target_value)
        
        # Calculate loss using Huber Loss
        loss = self.loss(estimated_value, target_value)
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        # Stuff for logging
        return loss.item()

# %%
##############################
# Training Environment Setup #
##############################

# Simplest moveset that can complete the level
NO_RUNNING = [
    ['right'],
    ['right', 'A']
]

env = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')
chosen_inputs = SIMPLE_MOVEMENT
env = JoypadSpace(env, chosen_inputs)

# Environment Preprocessing - Apply wrappers to the environment to reduce load on NN
num_skip_frames = 4
env = MaxAndSkipEnv(env, skip=num_skip_frames) # Skip the given number of frames
env = GrayScaleObservation(env) # Convert state from RGB to grayscale (1/3 number of pixels for NN to process)
env = ResizeObservation(env, shape=84) # Scale each frame to 64x64 pixels (15x fewer pixels for NN to process)
env = FrameStack(env, 4) # Stack the last 4 observations together to give NN temporal awareness
# Final observation shape: (        4         ,   84   ,   84    ,      1      )
#                           num_stacked_frames  height    width    num_channels

# %%
#######################
# Agent Training Loop #
#######################

resuming_training = False
saved_model_path = './models/20220418-175357/30000.pth'

if resuming_training:
    agent = Agent(len(chosen_inputs), model_path=saved_model_path) # Continue training existing model
else:
    agent = Agent(len(chosen_inputs)) # Train NEW agent, set resuming_training to false if training from scratch

num_episodes = 1000000
sync_interval = 10000 #(steps)
save_interval = 10000 #(steps)
log_interval = 20 #(episodes)
timestamp = time.strftime("%Y%m%d-%H%M%S")
save_location = './models/lr0.000025-no-target-network/' + timestamp + '/'
os.mkdir(save_location)

step = 1
rewards_per_episode = []
distance_per_episode = []
average_loss_per_episode = []
death_count = 0
timeout_count = 0
flag_count = 0
for episode in range(num_episodes):
    episode_loss = 0.0
    num_losses = 0
    average_episode_loss = 0.0
    episode_reward = 0.0
    num_episode_steps = 1
    state = env.reset()

    while True:
            
        # Choose and execute an action following epsilon-greedy policy
        chosen_action = agent.get_action(state)
        next_state, reward, done, info = env.step(chosen_action)
        episode_reward += reward
        
        # Add the transition to the replay buffer
        agent.add_to_replay_buffer(state, chosen_action, reward, next_state, done)
        
        # Update random sample of transitions from the replay buffer
        loss = agent.perform_updates()
        if loss is not None:
            episode_loss += loss
            num_losses += 1
            average_episode_loss = episode_loss / num_losses
        
        agent.decay_epsilon()
        
        if step % 10000 == 0:
            print("Done", step, "steps,", episode, "completed episodes")
            
        # Save model every so often
        if step % save_interval == 0:   
            agent.save_model(step, episode, save_location)
        
        #env.render()
        
        state = next_state
        step += 1 # Total steps over all episodes
        num_episode_steps += 1 # Steps in this episode
        
        if done:
            rewards_per_episode.append(episode_reward)
            distance_per_episode.append(info['x_pos'])
            average_loss_per_episode.append(average_episode_loss)
            
            if info['time'] == 0:
                timeout_count += 1
            elif info['flag_get']:
                flag_count += 1
            else:
                death_count += 1
            
            # Log episode stats
            if episode % log_interval == 0 and episode != 0:
                average_episode_reward = sum(rewards_per_episode) / len(rewards_per_episode)
                average_episode_distance = sum(distance_per_episode) / len(distance_per_episode)
                average_loss_across_episodes = sum(average_loss_per_episode) / len(average_loss_per_episode)
                agent.update_logs(save_location, log_interval, episode, step, average_loss_across_episodes, 
                                  average_episode_reward, average_episode_distance, flag_count, death_count, timeout_count)
                rewards_per_episode = []
                distance_per_episode = []
                average_loss_per_episode = []
                timeout_count = 0
                flag_count = 0
                death_count = 0
            
            break
# Out:
# Torch device:  cuda
# Updating logs
# Done 10000 steps, 34 completed episodes
# Updating logs
# Updating logs
# Done 20000 steps, 68 completed episodes
# Updating logs
# Done 30000 steps, 93 completed episodes
# Updating logs
# Updating logs
# Done 40000 steps, 123 completed episodes
# Done 50000 steps, 136 completed episodes
# Updating logs
# Done 60000 steps, 156 completed episodes
# Updating logs
# Done 70000 steps, 179 completed episodes
# Updating logs
# Updating logs
# Done 80000 steps, 201 completed episodes
# Updating logs
# Done 90000 steps, 230 completed episodes
# Updating logs
# Updating logs
# Done 100000 steps, 268 completed episodes
# Updating logs
# Done 110000 steps, 295 completed episodes
# Updating logs
# Updating logs
# Done 120000 steps, 326 completed episodes
# Updating logs
# Done 130000 steps, 347 completed episodes
# Updating logs
# Done 140000 steps, 366 completed episodes
# Updating logs
# Done 150000 steps, 393 completed episodes
# Updating logs
# Done 160000 steps, 417 completed episodes
# Updating logs
# Done 170000 steps, 435 completed episodes
# Updating logs
# Done 180000 steps, 458 completed episodes
# Updating logs
# Updating logs
# Done 190000 steps, 481 completed episodes
# Updating logs
# Done 200000 steps, 508 completed episodes
# Updating logs
# Done 210000 steps, 533 completed episodes
# Updating logs
# Done 220000 steps, 548 completed episodes
# Updating logs
# Done 230000 steps, 568 completed episodes
# Updating logs
# Done 240000 steps, 587 completed episodes
# Updating logs
# Done 250000 steps, 608 completed episodes
# Updating logs
# Done 260000 steps, 635 completed episodes
# Updating logs
# Done 270000 steps, 660 completed episodes
# Updating logs
# Updating logs
# Done 280000 steps, 683 completed episodes
# Updating logs
# Done 290000 steps, 712 completed episodes
# Updating logs
# Done 300000 steps, 735 completed episodes
# Updating logs
# Updating logs
# Done 310000 steps, 762 completed episodes
# Updating logs
# Done 320000 steps, 788 completed episodes
# Updating logs
# Done 330000 steps, 815 completed episodes
# Updating logs
# Updating logs
# Done 340000 steps, 844 completed episodes
# Updating logs
# Done 350000 steps, 869 completed episodes
# Updating logs
# Done 360000 steps, 886 completed episodes
# Updating logs
# Updating logs
# Done 370000 steps, 928 completed episodes
# Updating logs
# Done 380000 steps, 948 completed episodes
# Updating logs
# Done 390000 steps, 975 completed episodes
# Updating logs
# Done 400000 steps, 997 completed episodes
# Updating logs
# Done 410000 steps, 1013 completed episodes
# Updating logs
# Done 420000 steps, 1032 completed episodes
# Updating logs
# Done 430000 steps, 1055 completed episodes
# Updating logs
# Updating logs
# Done 440000 steps, 1086 completed episodes
# Updating logs
# Done 450000 steps, 1110 completed episodes
# Updating logs
# Updating logs
# Done 460000 steps, 1141 completed episodes
# Updating logs
# Done 470000 steps, 1176 completed episodes
# Updating logs
# Updating logs
# Done 480000 steps, 1215 completed episodes
# Updating logs
# Done 490000 steps, 1238 completed episodes
# Updating logs
# Done 500000 steps, 1258 completed episodes
# Updating logs
# Updating logs
# Done 510000 steps, 1296 completed episodes
# Updating logs
# Updating logs
# Done 520000 steps, 1328 completed episodes
# Updating logs
# Updating logs
# Done 530000 steps, 1365 completed episodes
# Updating logs
# Done 540000 steps, 1393 completed episodes
# Updating logs
# Done 550000 steps, 1415 completed episodes
# Updating logs
# Updating logs
# Done 560000 steps, 1450 completed episodes
# Updating logs
# Done 570000 steps, 1479 completed episodes
# Updating logs
# Updating logs
# Done 580000 steps, 1512 completed episodes
# Updating logs
# Done 590000 steps, 1540 completed episodes
# Updating logs
# Updating logs
# Done 600000 steps, 1569 completed episodes
# Updating logs
# Done 610000 steps, 1595 completed episodes
# Updating logs
# Updating logs
# Done 620000 steps, 1628 completed episodes
# Updating logs
# Done 630000 steps, 1659 completed episodes
# Updating logs
# Updating logs
# Done 640000 steps, 1698 completed episodes
# Updating logs
# Updating logs
# Done 650000 steps, 1733 completed episodes
# Updating logs
# Updating logs
# Done 660000 steps, 1770 completed episodes
# Updating logs
# Updating logs
# Done 670000 steps, 1806 completed episodes
# Updating logs
# Updating logs
# Done 680000 steps, 1847 completed episodes
# Updating logs
# Updating logs
# Done 690000 steps, 1883 completed episodes
# Updating logs
# Updating logs
# Done 700000 steps, 1927 completed episodes
# Updating logs
# Done 710000 steps, 1958 completed episodes
# Updating logs
# Updating logs
# Done 720000 steps, 1996 completed episodes
# Updating logs
# Updating logs
# Done 730000 steps, 2036 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 740000 steps, 2086 completed episodes
# Updating logs
# Updating logs
# Done 750000 steps, 2131 completed episodes
# Updating logs
# Updating logs
# Done 760000 steps, 2165 completed episodes
# Updating logs
# Done 770000 steps, 2193 completed episodes
# Updating logs
# Updating logs
# Done 780000 steps, 2231 completed episodes
# Updating logs
# Updating logs
# Done 790000 steps, 2269 completed episodes
# Updating logs
# Updating logs
# Done 800000 steps, 2303 completed episodes
# Updating logs
# Updating logs
# Done 810000 steps, 2343 completed episodes
# Updating logs
# Done 820000 steps, 2369 completed episodes
# Updating logs
# Done 830000 steps, 2398 completed episodes
# Updating logs
# Updating logs
# Done 840000 steps, 2435 completed episodes
# Updating logs
# Updating logs
# Done 850000 steps, 2467 completed episodes
# Updating logs
# Updating logs
# Done 860000 steps, 2501 completed episodes
# Updating logs
# Done 870000 steps, 2531 completed episodes
# Updating logs
# Updating logs
# Done 880000 steps, 2561 completed episodes
# Updating logs
# Done 890000 steps, 2596 completed episodes
# Updating logs
# Updating logs
# Done 900000 steps, 2640 completed episodes
# Updating logs
# Updating logs
# Done 910000 steps, 2676 completed episodes
# Updating logs
# Updating logs
# Done 920000 steps, 2710 completed episodes
# Updating logs
# Updating logs
# Done 930000 steps, 2742 completed episodes
# Updating logs
# Done 940000 steps, 2767 completed episodes
# Updating logs
# Updating logs
# Done 950000 steps, 2802 completed episodes
# Updating logs
# Updating logs
# Done 960000 steps, 2845 completed episodes
# Updating logs
# Updating logs
# Done 970000 steps, 2886 completed episodes
# Updating logs
# Updating logs
# Done 980000 steps, 2927 completed episodes
# Updating logs
# Updating logs
# Done 990000 steps, 2971 completed episodes
# Updating logs
# Updating logs
# Done 1000000 steps, 3012 completed episodes
# Updating logs
# Updating logs
# Done 1010000 steps, 3051 completed episodes
# Updating logs
# Updating logs
# Done 1020000 steps, 3086 completed episodes
# Updating logs
# Updating logs
# Done 1030000 steps, 3126 completed episodes
# Updating logs
# Updating logs
# Done 1040000 steps, 3171 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1050000 steps, 3221 completed episodes
# Updating logs
# Done 1060000 steps, 3258 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1070000 steps, 3309 completed episodes
# Updating logs
# Updating logs
# Done 1080000 steps, 3358 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1090000 steps, 3410 completed episodes
# Updating logs
# Updating logs
# Done 1100000 steps, 3459 completed episodes
# Updating logs
# Updating logs
# Done 1110000 steps, 3498 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1120000 steps, 3545 completed episodes
# Updating logs
# Updating logs
# Done 1130000 steps, 3590 completed episodes
# Updating logs
# Updating logs
# Done 1140000 steps, 3629 completed episodes
# Updating logs
# Updating logs
# Done 1150000 steps, 3669 completed episodes
# Updating logs
# Updating logs
# Done 1160000 steps, 3707 completed episodes
# Updating logs
# Updating logs
# Done 1170000 steps, 3751 completed episodes
# Updating logs
# Updating logs
# Done 1180000 steps, 3797 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1190000 steps, 3847 completed episodes
# Updating logs
# Updating logs
# Done 1200000 steps, 3897 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1210000 steps, 3955 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1220000 steps, 4009 completed episodes
# Updating logs
# Updating logs
# Done 1230000 steps, 4056 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1240000 steps, 4107 completed episodes
# Updating logs
# Updating logs
# Done 1250000 steps, 4153 completed episodes
# Updating logs
# Updating logs
# Done 1260000 steps, 4193 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1270000 steps, 4245 completed episodes
# Updating logs
# Updating logs
# Done 1280000 steps, 4295 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1290000 steps, 4343 completed episodes
# Updating logs
# Updating logs
# Done 1300000 steps, 4395 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1310000 steps, 4441 completed episodes
# Updating logs
# Updating logs
# Done 1320000 steps, 4486 completed episodes
# Updating logs
# Done 1330000 steps, 4520 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1340000 steps, 4577 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1350000 steps, 4635 completed episodes
# Updating logs
# Updating logs
# Done 1360000 steps, 4677 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1370000 steps, 4726 completed episodes
# Updating logs
# Updating logs
# Done 1380000 steps, 4777 completed episodes
# Updating logs
# Updating logs
# Done 1390000 steps, 4817 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1400000 steps, 4866 completed episodes
# Updating logs
# Updating logs
# Done 1410000 steps, 4903 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1420000 steps, 4964 completed episodes
# Updating logs
# Updating logs
# Done 1430000 steps, 5009 completed episodes
# Updating logs
# Updating logs
# Done 1440000 steps, 5047 completed episodes
# Updating logs
# Updating logs
# Done 1450000 steps, 5089 completed episodes
# Updating logs
# Updating logs
# Done 1460000 steps, 5140 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1470000 steps, 5187 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1480000 steps, 5252 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1490000 steps, 5316 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1500000 steps, 5366 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1510000 steps, 5426 completed episodes
# Updating logs
# Updating logs
# Done 1520000 steps, 5477 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1530000 steps, 5537 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1540000 steps, 5582 completed episodes
# Updating logs
# Updating logs
# Done 1550000 steps, 5628 completed episodes
# Updating logs
# Updating logs
# Done 1560000 steps, 5670 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1570000 steps, 5722 completed episodes
# Updating logs
# Updating logs
# Done 1580000 steps, 5769 completed episodes
# Updating logs
# Updating logs
# Done 1590000 steps, 5809 completed episodes
# Updating logs
# Updating logs
# Done 1600000 steps, 5859 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1610000 steps, 5916 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1620000 steps, 5963 completed episodes
# Updating logs
# Updating logs
# Done 1630000 steps, 6012 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1640000 steps, 6061 completed episodes
# Updating logs
# Updating logs
# Done 1650000 steps, 6116 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1660000 steps, 6170 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1670000 steps, 6232 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1680000 steps, 6298 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1690000 steps, 6356 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1700000 steps, 6408 completed episodes
# Updating logs
# Updating logs
# Done 1710000 steps, 6458 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1720000 steps, 6508 completed episodes
# Updating logs
# Updating logs
# Done 1730000 steps, 6554 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1740000 steps, 6619 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1750000 steps, 6671 completed episodes
# Updating logs
# Updating logs
# Done 1760000 steps, 6720 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1770000 steps, 6770 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1780000 steps, 6829 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1790000 steps, 6884 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1800000 steps, 6943 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1810000 steps, 7008 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1820000 steps, 7071 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1830000 steps, 7129 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1840000 steps, 7190 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1850000 steps, 7248 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1860000 steps, 7304 completed episodes
# Updating logs
# Updating logs
# Done 1870000 steps, 7357 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1880000 steps, 7409 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1890000 steps, 7476 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 1900000 steps, 7541 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1910000 steps, 7604 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1920000 steps, 7664 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1930000 steps, 7728 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1940000 steps, 7796 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 1950000 steps, 7866 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1960000 steps, 7921 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1970000 steps, 7982 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1980000 steps, 8043 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 1990000 steps, 8107 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2000000 steps, 8173 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2010000 steps, 8241 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2020000 steps, 8310 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2030000 steps, 8366 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2040000 steps, 8430 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2050000 steps, 8492 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2060000 steps, 8565 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2070000 steps, 8622 completed episodes
# Updating logs
# Updating logs
# Done 2080000 steps, 8680 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2090000 steps, 8739 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2100000 steps, 8799 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2110000 steps, 8861 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2120000 steps, 8928 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2130000 steps, 8993 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2140000 steps, 9055 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2150000 steps, 9119 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2160000 steps, 9179 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2170000 steps, 9229 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2180000 steps, 9286 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2190000 steps, 9358 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2200000 steps, 9414 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2210000 steps, 9483 completed episodes
# Updating logs
# Updating logs
# Done 2220000 steps, 9539 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2230000 steps, 9603 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2240000 steps, 9674 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2250000 steps, 9739 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2260000 steps, 9804 completed episodes
# Updating logs
# Updating logs
# Done 2270000 steps, 9854 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2280000 steps, 9908 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2290000 steps, 9969 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2300000 steps, 10031 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2310000 steps, 10087 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2320000 steps, 10147 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2330000 steps, 10213 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2340000 steps, 10271 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2350000 steps, 10330 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2360000 steps, 10383 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2370000 steps, 10441 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2380000 steps, 10507 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2390000 steps, 10572 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2400000 steps, 10640 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2410000 steps, 10700 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2420000 steps, 10763 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2430000 steps, 10821 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2440000 steps, 10883 completed episodes
# Updating logs
# Updating logs
# Done 2450000 steps, 10938 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2460000 steps, 10993 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2470000 steps, 11057 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2480000 steps, 11105 completed episodes
# Updating logs
# Updating logs
# Done 2490000 steps, 11151 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2500000 steps, 11216 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2510000 steps, 11265 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2520000 steps, 11326 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2530000 steps, 11386 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2540000 steps, 11445 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2550000 steps, 11505 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2560000 steps, 11569 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2570000 steps, 11628 completed episodes
# Updating logs
# Updating logs
# Done 2580000 steps, 11679 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2590000 steps, 11735 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2600000 steps, 11792 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2610000 steps, 11845 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2620000 steps, 11911 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2630000 steps, 11971 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2640000 steps, 12027 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2650000 steps, 12085 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2660000 steps, 12150 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2670000 steps, 12214 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2680000 steps, 12266 completed episodes
# Updating logs
# Updating logs
# Done 2690000 steps, 12318 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2700000 steps, 12386 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2710000 steps, 12444 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2720000 steps, 12507 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2730000 steps, 12569 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2740000 steps, 12626 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2750000 steps, 12681 completed episodes
# Updating logs
# Updating logs
# Done 2760000 steps, 12736 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2770000 steps, 12791 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2780000 steps, 12849 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2790000 steps, 12907 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2800000 steps, 12968 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2810000 steps, 13029 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2820000 steps, 13098 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2830000 steps, 13158 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2840000 steps, 13218 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2850000 steps, 13281 completed episodes
# Updating logs
# Updating logs
# Done 2860000 steps, 13337 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2870000 steps, 13395 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2880000 steps, 13463 completed episodes
# Updating logs
# Updating logs
# Done 2890000 steps, 13509 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2900000 steps, 13578 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2910000 steps, 13630 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2920000 steps, 13694 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2930000 steps, 13752 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2940000 steps, 13825 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2950000 steps, 13887 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2960000 steps, 13944 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2970000 steps, 14006 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 2980000 steps, 14066 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 2990000 steps, 14145 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3000000 steps, 14212 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3010000 steps, 14276 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3020000 steps, 14336 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3030000 steps, 14395 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3040000 steps, 14446 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3050000 steps, 14502 completed episodes
# Updating logs
# Updating logs
# Done 3060000 steps, 14547 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3070000 steps, 14607 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3080000 steps, 14671 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3090000 steps, 14731 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3100000 steps, 14781 completed episodes
# Updating logs
# Updating logs
# Done 3110000 steps, 14840 completed episodes
# Updating logs
# Updating logs
# Done 3120000 steps, 14877 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3130000 steps, 14933 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3140000 steps, 14989 completed episodes
# Updating logs
# Updating logs
# Done 3150000 steps, 15039 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3160000 steps, 15096 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3170000 steps, 15141 completed episodes
# Updating logs
# Done 3180000 steps, 15180 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3190000 steps, 15241 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3200000 steps, 15304 completed episodes
# Updating logs
# Updating logs
# Done 3210000 steps, 15360 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3220000 steps, 15425 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3230000 steps, 15487 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3240000 steps, 15556 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3250000 steps, 15614 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3260000 steps, 15670 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3270000 steps, 15737 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3280000 steps, 15802 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3290000 steps, 15864 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3300000 steps, 15938 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3310000 steps, 16002 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3320000 steps, 16076 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3330000 steps, 16138 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3340000 steps, 16199 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3350000 steps, 16253 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3360000 steps, 16328 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3370000 steps, 16392 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3380000 steps, 16466 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3390000 steps, 16530 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3400000 steps, 16593 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3410000 steps, 16648 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3420000 steps, 16706 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3430000 steps, 16768 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3440000 steps, 16837 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3450000 steps, 16906 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3460000 steps, 16971 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3470000 steps, 17033 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3480000 steps, 17094 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3490000 steps, 17151 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3500000 steps, 17212 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3510000 steps, 17270 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3520000 steps, 17331 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3530000 steps, 17401 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3540000 steps, 17463 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3550000 steps, 17523 completed episodes
# Updating logs
# Updating logs
# Done 3560000 steps, 17579 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3570000 steps, 17641 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3580000 steps, 17705 completed episodes
# Updating logs
# Updating logs
# Done 3590000 steps, 17755 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3600000 steps, 17826 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3610000 steps, 17887 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3620000 steps, 17957 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3630000 steps, 18016 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3640000 steps, 18088 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3650000 steps, 18152 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3660000 steps, 18226 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3670000 steps, 18296 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3680000 steps, 18350 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3690000 steps, 18415 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3700000 steps, 18472 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3710000 steps, 18525 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3720000 steps, 18586 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3730000 steps, 18643 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3740000 steps, 18706 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3750000 steps, 18775 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3760000 steps, 18838 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3770000 steps, 18906 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3780000 steps, 18988 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3790000 steps, 19059 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3800000 steps, 19128 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3810000 steps, 19192 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3820000 steps, 19256 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3830000 steps, 19320 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3840000 steps, 19388 completed episodes
# Updating logs
# Updating logs
# Done 3850000 steps, 19436 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3860000 steps, 19494 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3870000 steps, 19557 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3880000 steps, 19623 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3890000 steps, 19682 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3900000 steps, 19750 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3910000 steps, 19811 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3920000 steps, 19873 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3930000 steps, 19933 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3940000 steps, 20001 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3950000 steps, 20065 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3960000 steps, 20134 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 3970000 steps, 20201 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3980000 steps, 20267 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 3990000 steps, 20333 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4000000 steps, 20398 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4010000 steps, 20464 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4020000 steps, 20543 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4030000 steps, 20606 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4040000 steps, 20671 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4050000 steps, 20739 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4060000 steps, 20795 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4070000 steps, 20858 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4080000 steps, 20918 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4090000 steps, 20984 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4100000 steps, 21046 completed episodes
# Updating logs
# Updating logs
# Done 4110000 steps, 21099 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4120000 steps, 21160 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4130000 steps, 21223 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4140000 steps, 21300 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4150000 steps, 21363 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4160000 steps, 21425 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4170000 steps, 21495 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4180000 steps, 21566 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4190000 steps, 21630 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4200000 steps, 21694 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4210000 steps, 21753 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4220000 steps, 21807 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4230000 steps, 21866 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4240000 steps, 21927 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4250000 steps, 21988 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4260000 steps, 22051 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4270000 steps, 22115 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4280000 steps, 22170 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4290000 steps, 22235 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4300000 steps, 22290 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4310000 steps, 22355 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4320000 steps, 22412 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4330000 steps, 22483 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4340000 steps, 22545 completed episodes
# Updating logs
# Updating logs
# Done 4350000 steps, 22600 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4360000 steps, 22669 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4370000 steps, 22733 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4380000 steps, 22797 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4390000 steps, 22860 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4400000 steps, 22928 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4410000 steps, 22988 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4420000 steps, 23050 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4430000 steps, 23105 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4440000 steps, 23162 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4450000 steps, 23226 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4460000 steps, 23289 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4470000 steps, 23353 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4480000 steps, 23409 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4490000 steps, 23473 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4500000 steps, 23530 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4510000 steps, 23586 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4520000 steps, 23653 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4530000 steps, 23724 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4540000 steps, 23787 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4550000 steps, 23854 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4560000 steps, 23914 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4570000 steps, 23977 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4580000 steps, 24039 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4590000 steps, 24096 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4600000 steps, 24165 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4610000 steps, 24229 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4620000 steps, 24289 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4630000 steps, 24353 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4640000 steps, 24406 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4650000 steps, 24466 completed episodes
# Updating logs
# Updating logs
# Done 4660000 steps, 24518 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4670000 steps, 24578 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4680000 steps, 24634 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4690000 steps, 24691 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4700000 steps, 24751 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4710000 steps, 24812 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4720000 steps, 24881 completed episodes
# Updating logs
# Updating logs
# Done 4730000 steps, 24936 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4740000 steps, 25000 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4750000 steps, 25060 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4760000 steps, 25110 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4770000 steps, 25168 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4780000 steps, 25225 completed episodes
# Updating logs
# Updating logs
# Done 4790000 steps, 25280 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4800000 steps, 25340 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4810000 steps, 25408 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4820000 steps, 25471 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4830000 steps, 25533 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4840000 steps, 25593 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4850000 steps, 25663 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4860000 steps, 25726 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4870000 steps, 25794 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4880000 steps, 25854 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4890000 steps, 25916 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4900000 steps, 25973 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4910000 steps, 26030 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4920000 steps, 26081 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4930000 steps, 26144 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4940000 steps, 26212 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4950000 steps, 26274 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4960000 steps, 26336 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 4970000 steps, 26411 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 4980000 steps, 26463 completed episodes
# Updating logs
# Updating logs
# Done 4990000 steps, 26519 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 5000000 steps, 26586 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5010000 steps, 26644 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5020000 steps, 26714 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 5030000 steps, 26783 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5040000 steps, 26844 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5050000 steps, 26914 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 5060000 steps, 26982 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5070000 steps, 27046 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5080000 steps, 27111 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5090000 steps, 27169 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5100000 steps, 27231 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5110000 steps, 27285 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5120000 steps, 27348 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5130000 steps, 27413 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5140000 steps, 27473 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5150000 steps, 27532 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5160000 steps, 27589 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5170000 steps, 27643 completed episodes
# Updating logs
# Updating logs
# Done 5180000 steps, 27698 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 5190000 steps, 27762 completed episodes
# Updating logs
# Updating logs
# Done 5200000 steps, 27818 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5210000 steps, 27873 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5220000 steps, 27922 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5230000 steps, 27989 completed episodes
# Updating logs
# Updating logs
# Done 5240000 steps, 28038 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 5250000 steps, 28103 completed episodes
# Updating logs
# Updating logs
# Done 5260000 steps, 28151 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5270000 steps, 28218 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 5280000 steps, 28285 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5290000 steps, 28345 completed episodes
# Updating logs
# Updating logs
# Done 5300000 steps, 28394 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5310000 steps, 28452 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5320000 steps, 28514 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5330000 steps, 28563 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5340000 steps, 28624 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5350000 steps, 28684 completed episodes
# Updating logs
# Updating logs
# Done 5360000 steps, 28738 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5370000 steps, 28787 completed episodes
# Updating logs
# Updating logs
# Done 5380000 steps, 28840 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5390000 steps, 28897 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5400000 steps, 28953 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5410000 steps, 29009 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5420000 steps, 29064 completed episodes
# Updating logs
# Updating logs
# Done 5430000 steps, 29116 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5440000 steps, 29177 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5450000 steps, 29235 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5460000 steps, 29293 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5470000 steps, 29342 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5480000 steps, 29402 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5490000 steps, 29462 completed episodes
# Updating logs
# Updating logs
# Done 5500000 steps, 29517 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 5510000 steps, 29582 completed episodes
# Updating logs
# Updating logs
# Done 5520000 steps, 29638 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5530000 steps, 29695 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5540000 steps, 29753 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5550000 steps, 29816 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5560000 steps, 29870 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5570000 steps, 29928 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5580000 steps, 29981 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5590000 steps, 30043 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5600000 steps, 30102 completed episodes
# Updating logs
# Updating logs
# Done 5610000 steps, 30153 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5620000 steps, 30217 completed episodes
# Updating logs
# Updating logs
# Done 5630000 steps, 30255 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5640000 steps, 30318 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5650000 steps, 30373 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5660000 steps, 30426 completed episodes
# Updating logs
# Updating logs
# Done 5670000 steps, 30480 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5680000 steps, 30540 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5690000 steps, 30595 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5700000 steps, 30647 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5710000 steps, 30706 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5720000 steps, 30766 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5730000 steps, 30826 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5740000 steps, 30885 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5750000 steps, 30949 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5760000 steps, 31007 completed episodes
# Updating logs
# Updating logs
# Done 5770000 steps, 31056 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5780000 steps, 31110 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5790000 steps, 31173 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5800000 steps, 31235 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5810000 steps, 31298 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Updating logs
# Done 5820000 steps, 31363 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5830000 steps, 31425 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5840000 steps, 31486 completed episodes
# Updating logs
# Updating logs
# Done 5850000 steps, 31538 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5860000 steps, 31591 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5870000 steps, 31641 completed episodes
# Updating logs
# Updating logs
# Done 5880000 steps, 31698 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5890000 steps, 31750 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5900000 steps, 31806 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5910000 steps, 31861 completed episodes
# Updating logs
# Updating logs
# Done 5920000 steps, 31915 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5930000 steps, 31976 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5940000 steps, 32033 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5950000 steps, 32092 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5960000 steps, 32148 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5970000 steps, 32211 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 5980000 steps, 32262 completed episodes
# Updating logs
# Updating logs
# Done 5990000 steps, 32320 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6000000 steps, 32379 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6010000 steps, 32437 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6020000 steps, 32496 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6030000 steps, 32551 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6040000 steps, 32607 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6050000 steps, 32671 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6060000 steps, 32726 completed episodes
# Updating logs
# Updating logs
# Done 6070000 steps, 32778 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6080000 steps, 32833 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6090000 steps, 32887 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6100000 steps, 32942 completed episodes
# Updating logs
# Updating logs
# Done 6110000 steps, 32993 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6120000 steps, 33050 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6130000 steps, 33113 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6140000 steps, 33170 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6150000 steps, 33230 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6160000 steps, 33290 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6170000 steps, 33359 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6180000 steps, 33416 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6190000 steps, 33468 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6200000 steps, 33524 completed episodes
# Updating logs
# Updating logs
# Done 6210000 steps, 33574 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6220000 steps, 33627 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6230000 steps, 33688 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6240000 steps, 33741 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6250000 steps, 33806 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6260000 steps, 33863 completed episodes
# Updating logs
# Updating logs
# Done 6270000 steps, 33917 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6280000 steps, 33974 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6290000 steps, 34023 completed episodes
# Updating logs
# Updating logs
# Done 6300000 steps, 34078 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6310000 steps, 34132 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6320000 steps, 34184 completed episodes
# Updating logs
# Updating logs
# Done 6330000 steps, 34234 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6340000 steps, 34289 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6350000 steps, 34343 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6360000 steps, 34403 completed episodes
# Updating logs
# Updating logs
# Done 6370000 steps, 34455 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6380000 steps, 34517 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6390000 steps, 34569 completed episodes
# Updating logs
# Updating logs
# Done 6400000 steps, 34619 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6410000 steps, 34667 completed episodes
# Updating logs
# Updating logs
# Done 6420000 steps, 34718 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6430000 steps, 34767 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6440000 steps, 34823 completed episodes
# Updating logs
# Updating logs
# Done 6450000 steps, 34877 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6460000 steps, 34927 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6470000 steps, 34981 completed episodes
# Updating logs
# Updating logs
# Done 6480000 steps, 35037 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6490000 steps, 35095 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6500000 steps, 35146 completed episodes
# Updating logs
# Updating logs
# Done 6510000 steps, 35189 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6520000 steps, 35242 completed episodes
# Updating logs
# Updating logs
# Done 6530000 steps, 35292 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6540000 steps, 35347 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6550000 steps, 35401 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6560000 steps, 35462 completed episodes
# Updating logs
# Updating logs
# Done 6570000 steps, 35517 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6580000 steps, 35572 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6590000 steps, 35628 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6600000 steps, 35688 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6610000 steps, 35741 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6620000 steps, 35801 completed episodes
# Updating logs
# Updating logs
# Done 6630000 steps, 35848 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6640000 steps, 35902 completed episodes
# Updating logs
# Updating logs
# Done 6650000 steps, 35950 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6660000 steps, 36012 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6670000 steps, 36069 completed episodes
# Updating logs
# Updating logs
# Done 6680000 steps, 36118 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6690000 steps, 36180 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6700000 steps, 36237 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6710000 steps, 36289 completed episodes
# Updating logs
# Updating logs
# Done 6720000 steps, 36338 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6730000 steps, 36393 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6740000 steps, 36441 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6750000 steps, 36502 completed episodes
# Updating logs
# Updating logs
# Done 6760000 steps, 36553 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6770000 steps, 36607 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6780000 steps, 36674 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6790000 steps, 36722 completed episodes
# Updating logs
# Updating logs
# Done 6800000 steps, 36776 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6810000 steps, 36834 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6820000 steps, 36891 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6830000 steps, 36942 completed episodes
# Updating logs
# Updating logs
# Done 6840000 steps, 36994 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6850000 steps, 37049 completed episodes
# Updating logs
# Updating logs
# Done 6860000 steps, 37100 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6870000 steps, 37159 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6880000 steps, 37211 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6890000 steps, 37267 completed episodes
# Updating logs
# Updating logs
# Done 6900000 steps, 37316 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6910000 steps, 37369 completed episodes
# Updating logs
# Updating logs
# Done 6920000 steps, 37414 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6930000 steps, 37467 completed episodes
# Updating logs
# Updating logs
# Done 6940000 steps, 37518 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6950000 steps, 37565 completed episodes
# Updating logs
# Updating logs
# Done 6960000 steps, 37616 completed episodes
# Updating logs
# Updating logs
# Updating logs
# Done 6970000 steps, 37665 completed episodes
# Updating logs
# Updating logs
# Done 6980000 steps, 37716 completed episodes

# %%
env.close()
